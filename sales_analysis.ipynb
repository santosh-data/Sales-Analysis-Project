# %% [markdown]
# # Sales Analysis Project

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load the Excel file

# %%
df = pd.read_excel("sale_data.xlsx")

# %% [markdown]
# # Basic summary

# %%
print("Summary Statistics")
print(df.describe())
# Out:
# Summary Statistics
#                       Date  Units Sold  Unit Price      Revenue
# count                   10   10.000000    10.00000    10.000000
# mean   2025-01-05 12:00:00   94.000000    41.00000  4005.000000
# min    2025-01-01 00:00:00   60.000000    30.00000  1800.000000
# 25%    2025-01-03 06:00:00   81.250000    32.50000  2712.500000
# 50%    2025-01-05 12:00:00   92.500000    40.00000  3700.000000
# 75%    2025-01-07 18:00:00  107.500000    50.00000  5375.000000
# max    2025-01-10 00:00:00  130.000000    50.00000  6500.000000
# std                    NaN   21.832697     8.75595  1663.071122

# %% [markdown]
# # Revenue by Region

# %%
region_revenue = df.groupby('Region')['Revenue'].sum()
print("\n Total Revenue by  Region:")
print(region_revenue)
# Out:
#  Total Revenue by  Region:
# Region
# East     11500
# North    11150
# South    11800
# West      5600
# Name: Revenue, dtype: int64

# %% [markdown]
# # Plot revenue by region

# %%
region_revenue.plot(kind='bar', title='Total Revenue by Region', color='skyblue')
plt.ylabel('Revenue')
plt.xlabel('Region')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Top-selling product

# %%
top_products = df.groupby('Product')['Units Sold'].sum().sort_values(ascending=False)
print("\nTop-selling Products:")
print(top_products)
# Out:
# Top-selling Products:
# Product
# A    460
# B    265
# C    215
# Name: Units Sold, dtype: int64

# %% [markdown]
# # Monthly revenue trend

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Month'] = df['Date'].dt.to_period('M')
monthly_revenue = df.groupby('Month')['Revenue'].sum()

# %% [markdown]
# # Plot monthly revenue

# %%
monthly_revenue.plot(kind='line', marker='o',title='Monthly Revenue Trend', color='green')
plt.ylabel('Revenue')
plt.xlabel('Month')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\wvars\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\plotting\_matplotlib\core.py:1567: UserWarning: Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#   ax.set_xlim(left, right)
